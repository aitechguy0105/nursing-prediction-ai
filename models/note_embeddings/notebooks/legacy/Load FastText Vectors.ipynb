# %%
from gensim.models import KeyedVectors
import pandas as pd
import numpy as np
import re

from functools import lru_cache

train_start_date = '2017-01-01'
train_end_date = '2019-02-28'
test_end_date = '2019-06-26'

# %%
full_notes = pd.read_parquet(f's3://saiva-restricted-data/raw/avante_progress_notes_{train_start_date}_{test_end_date}.parquet')

# %%
def preprocess(strings):
    for s in strings:
        yield preprocess_one(s)

def preprocess_one(s):
    s = s.lower()
    tokens = re.split(r'\s', s)
    return tuple(t for t in tokens if len(t) > 0)

# %%
kv = KeyedVectors.load('/code/data/fasttext_keyed_vectors.kv')
# Out:
# /opt/conda/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
avg_vector = np.mean(kv.vectors, axis=0)

# %%
@lru_cache(maxsize=100000)
def vector_lookup(t):
    try:
        return kv[t]
    except KeyError:
        return avg_vector

def vectorize_note(s):
        tokens = preprocess_one(s)
        if tokens:
            note_vector = np.sum([vector_lookup(t) for t in tokens], axis=0)
            return note_vector
        else:
            return avg_vector

# %%
from multiprocessing import Pool

# %%
import os

# %%
pool = Pool(os.cpu_count() - 2)

# %%
vectors = pool.map(vectorize_note, full_notes['NoteText'])

# %%
vectors_df = pd.DataFrame.from_records(vectors)

vectors_df.columns = [f'e_{n}' for n in vectors_df.columns]

# %%
full_notes = pd.concat([full_notes.reset_index(), vectors_df], axis=1)

# %%
del vectors_df

# %%
import pickle

# %%
with open('/code/data/processed/avante_notes.pickle', 'wb') as f:
    pickle.dump(full_notes, f, protocol=4)

# %%
test_note = full_notes.iloc[-1]['NoteText']

# %%
len(full_notes)
# Out:
# 13886119

# %%
full_notes.index.get_level_values(7).value_counts()
# Out:
# Note Text                                                                              8945068
# Sx / Lavage (Yes or No)                                                                 150129
# FiO2                                                                                    150129
# Trach Care (Yes or No) with Narrative                                                   150129
# Resp. Rate (Pre / Post)                                                                 150129
# Heart Rate (Pre - Post)                                                                 150129
# SAN Treatment Time with Narrative                                                       150129
# Sa02 (Pre / Post)                                                                       150129
# Ambu Bag / O2 Tank / Spare Trach in place (Yes or No)                                   147592
# Narrative Note                                                                          147592
# Measured /Spontaneous Parameters: Sa02                                                  146155
# Ventilator Setting:  MODE                                                               146155
# Ventilator Settings:  TIDAL VOLUME/PRESSURE                                             146155
# Alarm Settings: LOW PRESSURE                                                            146155
# Treatment/Procedures:  ABG's                                                            146155
# Alarm Settings:  LOW EXHALED (VE)                                                       146155
# Treatment/Procedures: TREATMENT                                                         146155
# Ventilator Settings:  RATE                                                              146155
# Ventilator Settings:  PEAK FLOW                                                         146155
# Treatment/Prodedures: Sx / LAVAGE                                                       146155
# Measured /Spontaneous Parameters: MIN. VOLUME                                           146155
# Alarm Settings:  HIGH PRESSURE                                                          146155
# Ventilator Settings: Fio2                                                               146155
# Measured /Spontaneous Parameters: HEART RATE (PRE / POST)                               146155
# Measured /Spontaneous Parameters: Resp. Rate (Spont)                                    146155
# Measured /Spontaneous Parameters: TIDAL VOLUME                                          146155
# Measured /Spontaneous Parameters: Fio2                                                  146155
# Ventilator Settings: PEEP                                                               146155
# Measured /Spontaneous Parameters: P.I.P.                                                146155
# Ventilator Settings: PSV                                                                146155
#                                                                                         ...
# Physician Ordered Intervention                                                             383
# Family Notification (include who you contacted or left message for)                        383
# Description of Acute Medical Issue requiring transfer                                      383
# Body Check completed with description (Include all skin issues)                            383
# Describe Mouth Care and or render prior to transport completion                            383
# Skin Integrity (Description, Interventions)                                                158
# Fall(Equiptment,Devices,Intervention)                                                      158
# Pain (Pharmacological and Non-Pharmacological, Therapy Intervention)                       158
# Nutritional Status (Weight Changes + or -, Supplements, Diet Orders)                       158
# Rehospitalization (within 1 year)                                                          158
# Advanced Directives                                                                        158
# Labs/ Diagnostics (Abnormals)                                                              158
# Comments:                                                                                  158
# Infection Review (Recent Treatment, Isolation)                                             158
# Immunizations (Flu, Pneumo and PPD)                                                        158
# Behaviors (Describe/Devices, Interventions)                                                158
# QM/Radar/Fraility Report(Triggers >70% and Interventions)                                  158
# Psychotropics (Medication, AIMS, Non-Pharmacological Interventions)                        158
# ADL/Therapy (Declines, Interventions)                                                      158
# Activities (Participation/Preference)                                                      158
# I attest that I have examined the resident and agree with the findings of the ARNP.         28
# Measurements                                                                                 4
# Wound Type                                                                                   4
# Wound Edges                                                                                  4
# New Orders                                                                                   4
# Drainage and Odor                                                                            4
# Peri-wound                                                                                   4
# Undermining/Tunneling                                                                        4
# Wound bed Tissue                                                                             4
# Location                                                                                     4
# Name: Section, Length: 118, dtype: int64

# %%
full_notes.head()
# Out:
#                                                                                                                                                                              NoteText  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text   Ketoconazole Cream 2 %\n\tApply to bilateral ...
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  A skin observation was completed on, SCOTT STR...
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text           98.7-66-18-132/72 continue plan of care.
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  no c/o voiced this tour.resident takes meds we...
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  Resident A&O times 3, able to make needs known...
#
#                                                                                                                                                                                vector
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  [-34.967876, -10.116984, -35.538002, 67.07896,...
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  [-77.20341, 258.98798, -72.93674, 116.10251, 1...
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  [-0.06227255, 1.1612256, -1.2654214, 9.444483,...
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  [-44.405064, -69.823814, -119.374466, 32.02920...
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  [-61.400497, -155.34035, -54.70516, 8.950726, ...

# %%
full_notes.loc[full_notes['NoteText'] == 'Yes']
# Out:
#                                                                                                                                                                       NoteText  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType              CreatedDate             SectionSequence Section
# avante   17221706       388038    10         z R.T. Shift Note (7pm - 7am) 2017-01-01 00:33:01.013 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17221787       379157    10         z R.T. Shift Note (7pm - 7am) 2017-01-01 00:46:10.743 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17221881       411592    10         z R.T. Shift Note (7pm - 7am) 2017-01-01 01:16:22.807 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222024       404249    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 02:14:33.447 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222487       369080    10         z R.T. Shift Note (7pm - 7am) 2017-01-01 03:02:09.643 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222764       409771    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:21:27.153 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222830       391867    10         z R.T. Shift Note (7pm - 7am) 2017-01-01 04:24:02.447 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222959       381108    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:25:20.060 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17222974       402836    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:26:51.357 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223054       393306    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:33:42.010 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223097       404249    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:23:08.600 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223159       404836    6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:31:35.340 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223178       438       6          z R.T. Shift Note (7pm - 7am) 2017-01-01 05:28:41.647 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223236       320511    6          z R.T. Shift Note (7am-7pm)   2017-01-01 05:35:40.127 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
#          17223341       401918    10         z R.T. VENT CHECK NOTE        2017-01-01 06:31:36.047 29              Treatment/Procedures: TRACH CARE                        Yes
#          17224422       408898    21         z Trach Flow Sheet            2017-01-01 09:32:37.570 6               Trach Care (Yes or No) with Narrative                   Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          17224693       408570    21         z Trach Flow Sheet            2017-01-01 09:42:42.067 6               Trach Care (Yes or No) with Narrative                   Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          17224735       315471    21         z Trach Flow Sheet            2017-01-01 09:37:21.607 6               Trach Care (Yes or No) with Narrative                   Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          17224748       201812    21         z R.T. VENT CHECK NOTE        2017-01-01 09:40:57.357 21              Treatment/Procedures: TREATMENT                         Yes
#                                                                                                    29              Treatment/Procedures: TRACH CARE                        Yes
#          17224751       410775    21         z Trach Flow Sheet            2017-01-01 09:54:44.907 6               Trach Care (Yes or No) with Narrative                   Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          17224778       410666    21         z R.T. VENT CHECK NOTE        2017-01-01 09:51:45.540 21              Treatment/Procedures: TREATMENT                         Yes
#                                                                                                    29              Treatment/Procedures: TRACH CARE                        Yes
#          17224805       403037    21         z Trach Flow Sheet            2017-01-01 09:45:09.637 6               Trach Care (Yes or No) with Narrative                   Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          17227663       291163    19         z R.T. Shift Note (7am-7pm)   2017-01-01 17:17:56.867 2               Ambu Bag / O2 Tank / Spare Trach in place (Yes ...      Yes
# ...                                                                                                                                                                        ...
#          25213168       536694    4          z R.T. VENT CHECK NOTE        2019-02-25 00:41:31.247 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#          25213222       589009    4          z R.T. VENT CHECK NOTE        2019-02-25 03:06:04.977 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#                                                                                                    21              Treatment/Procedures: TREATMENT                         Yes
#          25213259       491362    4          z Trach Flow Sheet            2019-02-25 02:57:19.267 7               SAN Treatment Time with Narrative                       Yes
#          25213342       536765    4          z R.T. VENT CHECK NOTE        2019-02-25 03:03:59.453 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#                                                                                                    21              Treatment/Procedures: TREATMENT                         Yes
#          25213343       545774    4          z Trach Flow Sheet            2019-02-25 03:10:17.517 5               Sx / Lavage (Yes or No)                                 Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          25213354       535813    4          z R.T. VENT CHECK NOTE        2019-02-25 03:11:57.983 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#          25213447       593583    4          z R.T. VENT CHECK NOTE        2019-02-25 03:08:00.747 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#                                                                                                    21              Treatment/Procedures: TREATMENT                         Yes
#          25213468       554667    4          z Trach Flow Sheet            2019-02-25 02:55:20.700 7               SAN Treatment Time with Narrative                       Yes
#          25213469       535703    4          z R.T. VENT CHECK NOTE        2019-02-25 03:01:13.540 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#                                                                                                    21              Treatment/Procedures: TREATMENT                         Yes
#          25213497       463846    4          z Trach Flow Sheet            2019-02-25 03:09:08.877 5               Sx / Lavage (Yes or No)                                 Yes
#                                                                                                    7               SAN Treatment Time with Narrative                       Yes
#          25213498       536694    4          z R.T. VENT CHECK NOTE        2019-02-25 03:13:39.643 19              Treatment/Prodedures: Sx / LAVAGE                       Yes
#                                                                                                    21              Treatment/Procedures: TREATMENT                         Yes
#          25213564       554667    4          z R.T. Shift Note (7pm - 7am) 2019-02-25 05
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  [-0.06227255, 1.1612256, -1.2654214, 9.444483,...
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  [-44.405064, -69.823814, -119.374466, 32.02920...
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  [-61.400497, -155.34035, -54.70516, 8.950726, ...
#
#                                                                                                                                             0  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text -34.967876
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -77.203407
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  -0.062273
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text -44.405064
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -61.400497
#
#                                                                                                                                              1  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -10.116984
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  258.987976
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    1.161226
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -69.823814
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -155.340347
#
#                                                                                                                                              2  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -35.538002
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  -72.936737
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   -1.265421
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text -119.374466
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  -54.705158
#
#                                                                                                                                              3  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text   67.078957
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  116.102509
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    9.444483
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text   32.029205
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text    8.950726
#
#                                                                                                                                              4  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text -108.616386
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  135.238235
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   18.556273
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text -171.118866
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -123.336006
#
#                                                                                                                                              5  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  100.519669
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  105.968681
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    1.997604
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -25.778910
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text   72.488274
#
#                                                                                                                                              6  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text    6.509571
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  -97.621643
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  -10.535656
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text    0.263687
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  123.859200
#
#                                                                                                                                             7  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text -25.575071
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -68.923195
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  37.203003
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  96.029793
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -61.055389
#
#                                                                                                                                     ...  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section    ...
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  ...
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  ...
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  ...
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  ...
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  ...
#
#                                                                                                                                            290  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text   27.300659
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -151.775360
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    4.844214
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -48.214283
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text   74.040321
#
#                                                                                                                                            291  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text   18.002102
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -116.886086
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   -4.187387
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -29.323418
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text    5.359493
#
#                                                                                                                                            292  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -43.263775
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  127.423866
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   -6.266688
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -44.399540
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text   -1.479360
#
#                                                                                                                                            293  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text   44.420994
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -217.448608
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   16.259949
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text   31.991673
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  206.780945
#
#                                                                                                                                            294  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -60.039364
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  -75.750168
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  -27.579540
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -66.514771
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -163.656525
#
#                                                                                                                                           295  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  84.271309
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  53.329865
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text  -0.664464
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  72.265961
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text -96.320419
#
#                                                                                                                                            296  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -54.068474
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -114.793877
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    6.138464
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text   63.012627
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text   67.976273
#
#                                                                                                                                            297  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -39.837219
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -149.095291
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   -1.903410
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text   29.912403
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text   47.839260
#
#                                                                                                                                           298  \
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  48.489815
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  74.077911
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   1.459381
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text -16.558504
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  49.563931
#
#                                                                                                                                            299
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -87.552116
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -108.858856
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    8.054781
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -40.953609
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  -24.667557
#
# [5 rows x 302 columns]

# %%
def seriesify(x):
    return pd.Series(x)

# %%
pool = Pool(processes=12)
# Out:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()

# %%
embeddings = pool.map(seriesify, full_notes['vector'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-bf4ee1b1572f> in <module>
# ----> 1 embeddings = pool.map(seriesify, full_notes['vector'])
#
# /opt/conda/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# /opt/conda/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# /opt/conda/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(resp)
# Out:
#          0           1           2           3           4           5    \
# 0 -34.967876  -10.116984  -35.538002   67.078957 -108.616386  100.519669
# 1 -77.203407  258.987976  -72.936737  116.102509  135.238235  105.968681
# 2  -0.062273    1.161226   -1.265421    9.444483   18.556273    1.997604
# 3 -44.405064  -69.823814 -119.374466   32.029205 -171.118866  -25.778910
# 4 -61.400497 -155.340347  -54.705158    8.950726 -123.336006   72.488274
#
#           6          7          8           9    ...         290         291  \
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text  74.077911
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text   1.459381
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text -16.558504
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  49.563931
#
#                                                                                                                                            299
# provider ProgressNoteID PatientID FacilityID ProgressNoteType                    CreatedDate             SectionSequence Section
# avante   17221143       366254    21         eMAR-Medication Administration Note 2017-01-01 00:08:01.257 1               Note Text  -87.552116
#          17221144       140573    3          Weekly Nurses Skin Observation Note 2017-01-01 00:37:48.507 1               Note Text -108.858856
#          17221174       409644    18         * Skilled Nursing Note              2017-01-01 00:11:47.527 1               Note Text    8.054781
#          17221233       179253    18         * Skilled Nursing Note              2017-01-01 00:01:52.583 1               Note Text  -40.953609
#          17221234       307860    13         * General NURSING Note              2017-01-01 00:04:25.697 1               Note Text  -24.667557
#
# [5 rows x 300 columns]

# %%
pd.concat([full_notes.head(),pd.DataFrame(data=full_notes['vector'].head().apply(lambda x: x.tolist()).tolist(), columns=[f'e_{n}' for n in range(0,300)])], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-a798b785afc4> in <module>
# ----> 1 pd.concat([full_notes.head(),pd.DataFrame(data=full_notes['vector'].head().apply(lambda x: x.tolist()).tolist(), columns=[f'e_{n}' for n in range(0,300)])], axis=1)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     379         self.copy = copy
#     380
# --> 381         self.new_axes = self._get_new_axes()
#     382
#     383     def get_result(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     446                 if i == self.axis:
#     447                     continue
# --> 448                 new_axes[i] = self._get_comb_axis(i)
#     449         else:
#     450             if len(self.join_axes) != ndim - 1:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_comb_axis(self, i)
#     467             return _get_objs_combined_axis(self.objs, axis=data_axis,
#     468                                            intersect=self.intersect,
# --> 469                                            sort=self.sort)
#     470         except IndexError:
#     471             types = [type(x).__name__ for x in self.objs]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/api.py in _get_objs_combined_axis(objs, intersect, axis, sort)
#      68                  if hasattr(obj, '_get_axis')]
#      69     if obs_idxes:
# ---> 70         return _get_combined_index(obs_idxes, intersect=intersect, sort=sort)
#      71
#      72
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/api.py in _get_combined_index(indexes, intersect, sort)
#     115             index = index.intersection(other)
#     116     else:
# --> 117         index = _union_indexes(indexes, sort=sort)
#     118         index = ensure_index(index)
#     119
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/api.py in _union_indexes(indexes, sort)
#     181         else:
#     182             for other in indexes[1:]:
# --> 183                 result = result.union(other)
#     184             return result
#     185     elif kind == 'array':
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/multi.py in union(self, other, sort)
#    2923         uniq_tuples = lib.fast_unique_multiple([self._ndarray_values,
#    2924                                                 other._ndarray_values],
# -> 2925                                                sort=sort)
#    2926
#    2927         return MultiIndex.from_arrays(lzip(*uniq_tuples), sortorder=0,
#
# pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long'

# %%
full_notes.to_pickle(f'/code/data/full_notes_with_vectors_{train_start_date}_{train_end_date}.p')

# %%
import s3fs

# %%
import boto3

# %%
s3 = boto3.resource('s3')

# %%
s3.Bucket('saiva-restricted-data').upload_file(f'/code/data/full_notes_with_vectors_{train_start_date}_{train_end_date}.p', f'processed/full_notes_with_vectors_{train_start_date}_{train_end_date}.p')
